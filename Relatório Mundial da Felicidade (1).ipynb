# %% [markdown]
#    # Introdução

# %% [markdown]
# ## No conjunto de dados, retirados do Gallup World Poll, referente aos países mais felizes do mundo no ano de 2023 e 2022, os países estão organizados em ordem crescente, apresentando o país mais feliz no topo e o menos feliz na parte inferior.
#
# ## Esta análise se propõe a explorar não apenas o ranking em si, mas também a identificação das características distintas entre os países mais felizes e os menos felizes. Vamos examinar as variáveis que contribuem para essas classificações e entender as razões por trás de suas posições no índice de felicidade.
#
# ## No decorrer dessa exploração, daremos atenção especial ao Brasil, destacando sua posição no cenário global de felicidade e investigando fatores específicos que podem influenciar seu desempenho neste ranking. A análise detalhada do Brasil permitirá uma compreensão mais profunda de sua situação em relação aos demais países e insights sobre áreas que podem ser aprimoradas para melhorar a qualidade de vida e a felicidade de sua população.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("DataForFigure2.1WHR2023.xls")

# %%
data
# Out:
#                   Country name  Ladder score  Standard error of ladder score  \
# 0                      Finland        7.8042                        0.036162
# 1                      Denmark        7.5864                        0.041028
# 2                      Iceland        7.5296                        0.048612
# 3                       Israel        7.4729                        0.031609
# 4                  Netherlands        7.4030                        0.029294
# 5                       Sweden        7.3952                        0.037362
# 6                       Norway        7.3155                        0.044143
# 7                  Switzerland        7.2401                        0.042789
# 8                   Luxembourg        7.2279                        0.069081
# 9                  New Zealand        7.1229                        0.038227
# 10                     Austria        7.0973                        0.040401
# ...

# %%
data.shape
# Out:
# (137, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 19 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                137 non-null    object
#  1   Ladder score                                137 non-null    float64
#  2   Standard error of ladder score              137 non-null    float64
#  3   upperwhisker                                137 non-null    float64
#  4   lowerwhisker                                137 non-null    float64
#  5   Logged GDP per capita                       137 non-null    float64
#  6   Social support                              137 non-null    float64
#  7   Healthy life expectancy                     136 non-null    float64
#  8   Freedom to make life choices                137 non-null    float64
# ...

# %% [markdown]
# ##  Vamos separar esse dataset, com todos os países e as suas pontuações totais.

# %%
data_country_score = data[["Country name", "Ladder score"]]

# %%
data_country_score.head(10)
# Out:
#   Country name  Ladder score
# 0      Finland        7.8042
# 1      Denmark        7.5864
# 2      Iceland        7.5296
# 3       Israel        7.4729
# 4  Netherlands        7.4030
# 5       Sweden        7.3952
# 6       Norway        7.3155
# 7  Switzerland        7.2401
# 8   Luxembourg        7.2279
# 9  New Zealand        7.1229

# %% [markdown]
# ##  Gráfico dos 10 países mais felizes do mundo em ordem.

# %%
 sns.barplot(x="Ladder score", y="Country name", data=data_country_score.head(10))
# Out:
# <Axes: xlabel='Ladder score', ylabel='Country name'>

# %% [markdown]
# ## Gráfico dos 10 ultimos países menos felizes do mundo

# %%
sns.barplot(x="Ladder score", y="Country name", data=data_country_score.tail(10))
# Out:
# <Axes: xlabel='Ladder score', ylabel='Country name'>

# %% [markdown]
# ##  Porcentagem das notas totais(Ladder score) de 2023.

# %%
data['nota_arredondada_score'] = data['Ladder score'].round(0)

# %%
data
# Out:
#                   Country name  Ladder score  Standard error of ladder score  \
# 0                      Finland        7.8042                        0.036162
# 1                      Denmark        7.5864                        0.041028
# 2                      Iceland        7.5296                        0.048612
# 3                       Israel        7.4729                        0.031609
# 4                  Netherlands        7.4030                        0.029294
# 5                       Sweden        7.3952                        0.037362
# 6                       Norway        7.3155                        0.044143
# 7                  Switzerland        7.2401                        0.042789
# 8                   Luxembourg        7.2279                        0.069081
# 9                  New Zealand        7.1229                        0.038227
# 10                     Austria        7.0973                        0.040401
# ...

# %%
notas_counts_2023 = data['nota_arredondada_score'].value_counts()

# %%
notas_counts_2023
# Out:
# nota_arredondada_score
# 6.0    49
# 5.0    33
# 7.0    24
# 4.0    21
# 3.0     5
# 8.0     3
# 2.0     2
# Name: count, dtype: int64

# %%
porcentagens2023 = (notas_counts_2023 / notas_counts_2023.sum()) * 100

# %%
porcentagens2023
# Out:
# nota_arredondada_score
# 6.0    35.766423
# 5.0    24.087591
# 7.0    17.518248
# 4.0    15.328467
# 3.0     3.649635
# 8.0     2.189781
# 2.0     1.459854
# Name: count, dtype: float64

# %% [markdown]
# ##  Porcentagens 2023

# %%
porcentagens_formatadas_2023 = porcentagens2023.apply(lambda x: f"{x:.2f}%")
porcentagens_formatadas_2023
# Out:
# nota_arredondada_score
# 6.0    35.77%
# 5.0    24.09%
# 7.0    17.52%
# 4.0    15.33%
# 3.0     3.65%
# 8.0     2.19%
# 2.0     1.46%
# Name: count, dtype: object

# %% [markdown]
# ## Expandindo todo meu dataset

# %%
pd.set_option('display.max_rows', None)
data
# Out:
#                   Country name  Ladder score  Standard error of ladder score  \
# 0                      Finland        7.8042                        0.036162
# 1                      Denmark        7.5864                        0.041028
# 2                      Iceland        7.5296                        0.048612
# 3                       Israel        7.4729                        0.031609
# 4                  Netherlands        7.4030                        0.029294
# 5                       Sweden        7.3952                        0.037362
# 6                       Norway        7.3155                        0.044143
# 7                  Switzerland        7.2401                        0.042789
# 8                   Luxembourg        7.2279                        0.069081
# 9                  New Zealand        7.1229                        0.038227
# 10                     Austria        7.0973                        0.040401
# ...

# %% [markdown]
# ## Percepção sobre a corrupção 2023

# %%
data_country_score_corrupion = data[['Country name','Explained by: Perceptions of corruption']]

# %%
data_country_score_corrupion
# Out:
#                   Country name  Explained by: Perceptions of corruption
# 0                      Finland                                 0.535299
# 1                      Denmark                                 0.525221
# 2                      Iceland                                 0.187119
# 3                       Israel                                 0.158292
# 4                  Netherlands                                 0.394062
# 5                       Sweden                                 0.520469
# 6                       Norway                                 0.462955
# 7                  Switzerland                                 0.474700
# 8                   Luxembourg                                 0.418380
# 9                  New Zealand                                 0.471221
# 10                     Austria                                 0.309653
# 11                   Australia                                 0.310268
# ...

# %%
corrupion_ordenado = data_country_score_corrupion.sort_values(by='Explained by: Perceptions of corruption', ascending=False)

# %%
# Países em ordem 

corrupion_ordenado
# Out:
#                   Country name  Explained by: Perceptions of corruption
# 24                   Singapore                                 0.560821
# 0                      Finland                                 0.535299
# 1                      Denmark                                 0.525221
# 5                       Sweden                                 0.520469
# 7                  Switzerland                                 0.474700
# 9                  New Zealand                                 0.471221
# 6                       Norway                                 0.462955
# 8                   Luxembourg                                 0.418380
# 13                     Ireland                                 0.409087
# 4                  Netherlands                                 0.394062
# 81   Hong Kong S.A.R. of China                                 0.389993
# 30                     Estonia                                 0.372188
# ...

# %%
## Colocando o index em ordem.

corrupion_ordenado = corrupion_ordenado.reset_index(drop=True)
corrupion_ordenado
# Out:
#                   Country name  Explained by: Perceptions of corruption
# 0                    Singapore                                 0.560821
# 1                      Finland                                 0.535299
# 2                      Denmark                                 0.525221
# 3                       Sweden                                 0.520469
# 4                  Switzerland                                 0.474700
# 5                  New Zealand                                 0.471221
# 6                       Norway                                 0.462955
# 7                   Luxembourg                                 0.418380
# 8                      Ireland                                 0.409087
# 9                  Netherlands                                 0.394062
# 10   Hong Kong S.A.R. of China                                 0.389993
# 11                     Estonia                                 0.372188
# ...

# %%
corrupion_ordenado
# Out:
#                   Country name  Explained by: Perceptions of corruption
# 0                    Singapore                                 0.560821
# 1                      Finland                                 0.535299
# 2                      Denmark                                 0.525221
# 3                       Sweden                                 0.520469
# 4                  Switzerland                                 0.474700
# 5                  New Zealand                                 0.471221
# 6                       Norway                                 0.462955
# 7                   Luxembourg                                 0.418380
# 8                      Ireland                                 0.409087
# 9                  Netherlands                                 0.394062
# 10   Hong Kong S.A.R. of China                                 0.389993
# 11                     Estonia                                 0.372188
# ...

# %%
sns.barplot(x="Explained by: Perceptions of corruption", y="Country name", data=corrupion_ordenado.head(10))
# Out:
# <Axes: xlabel='Explained by: Perceptions of corruption', ylabel='Country name'>

# %% [markdown]
# ## Em 2023 dos 10 países considerados os mais felizes do mundo, 80% deles estão classificados entre os 10 com a melhor percepção sobre a corrupção no ano de 2023.

# %% [markdown]
# ## Vamos pegar a variavel 'Ladder score in Dystopia' que reflete quão bem um país se posiciona em relação a um cenário teoricamente terrível, conhecido como 'Dystopia'

# %%
data_Score_Dystopia = data[['Country name','Dystopia + residual']]

# %%
data_Score_Dystopia
# Out:
#                   Country name  Dystopia + residual
# 0                      Finland             2.363241
# 1                      Denmark             2.083766
# 2                      Iceland             2.250382
# 3                       Israel             2.691290
# 4                  Netherlands             2.110044
# 5                       Sweden             1.903127
# 6                       Norway             1.829270
# 7                  Switzerland             1.869847
# 8                   Luxembourg             1.845181
# 9                  New Zealand             1.851519
# 10                     Austria             2.123896
# 11                   Australia             1.937743
# 12                      Canada             1.815377
# 13                     Ireland             1.544905
# 14               United States             2.124348
# 15                     Germany             1.897525
# 16                     Belgium             1.975743
# ...

# %%
data_Score_Dystopia_Ordenado = data_Score_Dystopia.sort_values(by='Dystopia + residual', ascending=False)

# %%
data_Score_Dystopia_Ordenado
# Out:
#                   Country name  Dystopia + residual
# 87                   Venezuela             2.954561
# 85         Congo (Brazzaville)             2.802217
# 90                      Guinea             2.704875
# 3                       Israel             2.691290
# 52                    Honduras             2.630738
# 42                   Guatemala             2.561968
# 96                  Mozambique             2.519486
# 92                 Ivory Coast             2.518610
# 23                     Romania             2.485311
# 39                   Nicaragua             2.448323
# 95                    Cameroon             2.410614
# 49                 El Salvador             2.403147
# 33                      Kosovo             2.392719
# 35                      Mexico             2.388729
# 19                   Lithuania             2.377429
# 0                      Finland             2.363241
# 108                      Niger             2.341015
# ...

# %%
data_Score_Dystopia_Ordenado_index = data_Score_Dystopia_Ordenado.reset_index(drop=True)

# %%
data_Score_Dystopia_Ordenado_index
# Out:
#                   Country name  Dystopia + residual
# 0                    Venezuela             2.954561
# 1          Congo (Brazzaville)             2.802217
# 2                       Guinea             2.704875
# 3                       Israel             2.691290
# 4                     Honduras             2.630738
# 5                    Guatemala             2.561968
# 6                   Mozambique             2.519486
# 7                  Ivory Coast             2.518610
# 8                      Romania             2.485311
# 9                    Nicaragua             2.448323
# 10                    Cameroon             2.410614
# 11                 El Salvador             2.403147
# 12                      Kosovo             2.392719
# 13                      Mexico             2.388729
# 14                   Lithuania             2.377429
# 15                     Finland             2.363241
# 16                       Niger             2.341015
# ...

# %%
sns.barplot(x="Dystopia + residual", y="Country name", data=data_Score_Dystopia_Ordenado_index.head(10))
# Out:
# <Axes: xlabel='Dystopia + residual', ylabel='Country name'>

# %% [markdown]
# ## Observando o ano de 2023, percebemos que Israel é consistentemente classificado em 4º lugar nos índices de felicidade global, destacando-se como o único país que mantém essa posição tanto em condições normais quanto em cenários teoricamente desafiadores.

# %% [markdown]
# # Dados 2022

# %%
data2022 = pd.read_excel("Appendix_2_Data_for_Figure_2.1.2022.xls")

# %%
data2022.head()
# Out:
#    RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1      Finland           7.8210      7.886425     7.755575
# 1     2      Denmark           7.6362      7.709897     7.562503
# 2     3      Iceland           7.5575      7.651076     7.463924
# 3     4  Switzerland           7.5116      7.586394     7.436806
# 4     5  Netherlands           7.4149      7.471265     7.358534
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                    2.518052                      1.891628
# 1                    2.225632                      1.952595
# 2                    2.320185                      1.935726
# 3                    2.152746                      2.025970
# 4                    2.136937                      1.944578
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                      1.258108                               0.775206
# ...

# %%
pd.set_option('display.max_rows', None)
data2022
# Out:
#      RANK                    Country  Happiness score  Whisker-high  \
# 0       1                    Finland           7.8210      7.886425
# 1       2                    Denmark           7.6362      7.709897
# 2       3                    Iceland           7.5575      7.651076
# 3       4                Switzerland           7.5116      7.586394
# 4       5                Netherlands           7.4149      7.471265
# 5       6                Luxembourg*           7.4040      7.501348
# 6       7                     Sweden           7.3843      7.454091
# 7       8                     Norway           7.3651      7.439799
# 8       9                     Israel           7.3638      7.426288
# 9      10                New Zealand           7.1998      7.279399
# 10     11                    Austria           7.1630      7.236605
# 11     12                  Australia           7.1621      7.243522
# 12     13                    Ireland           7.0408      7.120752
# ...

# %%
data2022_country_score = data2022[["Country","RANK", "Happiness score"]]
data2022_country_score
# Out:
#                        Country  RANK  Happiness score
# 0                      Finland     1           7.8210
# 1                      Denmark     2           7.6362
# 2                      Iceland     3           7.5575
# 3                  Switzerland     4           7.5116
# 4                  Netherlands     5           7.4149
# 5                  Luxembourg*     6           7.4040
# 6                       Sweden     7           7.3843
# 7                       Norway     8           7.3651
# 8                       Israel     9           7.3638
# 9                  New Zealand    10           7.1998
# 10                     Austria    11           7.1630
# 11                   Australia    12           7.1621
# 12                     Ireland    13           7.0408
# 13                     Germany    14           7.0341
# 14                      Canada    15           7.0251
# 15               United States    16           6.9768
# ...

# %% [markdown]
# ##  Gráfico dos 10 países mais felizes do mundo em 2022.

# %%
sns.barplot(x="Happiness score", y="Country", data=data2022_country_score.head(10))
# Out:
# <Axes: xlabel='Happiness score', ylabel='Country'>

# %% [markdown]
# ##  Gráfico dos 10 países menos felizes do mundo em 2022.

# %%
sns.barplot(x="Happiness score", y="Country", data=data2022_country_score.tail(10))
# Out:
# <Axes: xlabel='Happiness score', ylabel='Country'>

# %% [markdown]
# ## Porcentagem das notas totais de 2022

# %%
data2022['nota_arredondada_score'] = data2022['Happiness score'].round(0)

# %%
data2022
# Out:
#      RANK                    Country  Happiness score  Whisker-high  \
# 0       1                    Finland           7.8210      7.886425
# 1       2                    Denmark           7.6362      7.709897
# 2       3                    Iceland           7.5575      7.651076
# 3       4                Switzerland           7.5116      7.586394
# 4       5                Netherlands           7.4149      7.471265
# 5       6                Luxembourg*           7.4040      7.501348
# 6       7                     Sweden           7.3843      7.454091
# 7       8                     Norway           7.3651      7.439799
# 8       9                     Israel           7.3638      7.426288
# 9      10                New Zealand           7.1998      7.279399
# 10     11                    Austria           7.1630      7.236605
# 11     12                  Australia           7.1621      7.243522
# 12     13                    Ireland           7.0408      7.120752
# ...

# %%
notas_counts_2022 = data2022['nota_arredondada_score'].value_counts()
notas_counts_2022
# Out:
# nota_arredondada_score
# 6.0    50
# 5.0    45
# 7.0    22
# 4.0    20
# 8.0     4
# 3.0     4
# 2.0     1
# Name: count, dtype: int64

# %%
porcentagens2022 = (notas_counts_2022 / notas_counts_2022.sum()) * 100

# %%
porcentagens2022
# Out:
# nota_arredondada_score
# 6.0    34.246575
# 5.0    30.821918
# 7.0    15.068493
# 4.0    13.698630
# 8.0     2.739726
# 3.0     2.739726
# 2.0     0.684932
# Name: count, dtype: float64

# %%
porcentagens2023
# Out:
# nota_arredondada_score
# 6.0    35.766423
# 5.0    24.087591
# 7.0    17.518248
# 4.0    15.328467
# 3.0     3.649635
# 8.0     2.189781
# 2.0     1.459854
# Name: count, dtype: float64

# %% [markdown]
# ## Porcentagem 2022

# %%
porcentagens_formatadas_2022 = porcentagens2022.apply(lambda x: f"{x:.2f}%")
porcentagens_formatadas_2022
# Out:
# nota_arredondada_score
# 6.0    34.25%
# 5.0    30.82%
# 7.0    15.07%
# 4.0    13.70%
# 8.0     2.74%
# 3.0     2.74%
# 2.0     0.68%
# Name: count, dtype: object

# %% [markdown]
# ## Em 2023, nota 5.0 diminuiu para 24.09%, sugerindo uma possível redução na satisfação global, enquanto a nota 7.0 aumentou para 17.52%, indicando uma elevação relativa na felicidade em algumas regiões.

# %%
porcentagens_formatadas_2022
# Out:
# nota_arredondada_score
# 6.0    34.25%
# 5.0    30.82%
# 7.0    15.07%
# 4.0    13.70%
# 8.0     2.74%
# 3.0     2.74%
# 2.0     0.68%
# Name: count, dtype: object

# %%
porcentagens_formatadas_2023
# Out:
# nota_arredondada_score
# 6.0    35.77%
# 5.0    24.09%
# 7.0    17.52%
# 4.0    15.33%
# 3.0     3.65%
# 8.0     2.19%
# 2.0     1.46%
# Name: count, dtype: object

# %% [markdown]
# ##  Percepção sobre a corrupção 2022

# %%
data_country_score_corrupion_2022 = data2022[['Country','Explained by: Perceptions of corruption']]

# %%
data_country_score_corrupion_2022
# Out:
#                        Country  Explained by: Perceptions of corruption
# 0                      Finland                                 0.533658
# 1                      Denmark                                 0.532079
# 2                      Iceland                                 0.191204
# 3                  Switzerland                                 0.461004
# 4                  Netherlands                                 0.419083
# 5                  Luxembourg*                                 0.388120
# 6                       Sweden                                 0.512238
# 7                       Norway                                 0.473999
# 8                       Israel                                 0.142614
# 9                  New Zealand                                 0.483003
# 10                     Austria                                 0.329127
# 11                   Australia                                 0.341046
# ...

# %%
corrupion_ordenado2022 = data_country_score_corrupion_2022.sort_values(by='Explained by: Perceptions of corruption', ascending=False)

# %%
corrupion_ordenado_2022 = corrupion_ordenado2022.reset_index(drop=True)
corrupion_ordenado_2022
# Out:
#                        Country  Explained by: Perceptions of corruption
# 0                    Singapore                                 0.586828
# 1                      Rwanda*                                 0.544236
# 2                      Finland                                 0.533658
# 3                      Denmark                                 0.532079
# 4                       Sweden                                 0.512238
# 5                  New Zealand                                 0.483003
# 6                       Norway                                 0.473999
# 7                  Switzerland                                 0.461004
# 8                  Netherlands                                 0.419083
# 9                      Ireland                                 0.407679
# 10                 Luxembourg*                                 0.388120
# 11   Hong Kong S.A.R. of China                                 0.382751
# ...

# %% [markdown]
# ##  Vamos pegar a variavel 'Ladder score in Dystopia' que reflete quão bem um país se posiciona em relação a um cenário teoricamente terrível, conhecido como 'Dystopia no ano de 2022.

# %%
data_Score_Dystopia_2022 = data2022[['Country','Dystopia (1.83) + residual']]

# %%
data_Score_Dystopia_2022
# Out:
#                        Country  Dystopia (1.83) + residual
# 0                      Finland                    2.518052
# 1                      Denmark                    2.225632
# 2                      Iceland                    2.320185
# 3                  Switzerland                    2.152746
# 4                  Netherlands                    2.136937
# 5                  Luxembourg*                    2.041680
# 6                       Sweden                    2.003476
# 7                       Norway                    1.924584
# 8                       Israel                    2.634107
# 9                  New Zealand                    1.953583
# 10                     Austria                    2.147515
# 11                   Australia                    2.011332
# 12                     Ireland                    1.743192
# 13                     Germany                    2.141650
# 14                      Canada                    1.923639
# ...

# %%
data_Score_Dystopia_Ordenado_2022 = data_Score_Dystopia_2022.sort_values(by='Dystopia (1.83) + residual', ascending=False)

# %%
data_Score_Dystopia_Ordenado_2022
# Out:
#                        Country  Dystopia (1.83) + residual
# 96                    Liberia*                    2.844388
# 107                  Venezuela                    2.790293
# 38                  Guatemala*                    2.746166
# 103                     Niger*                    2.666880
# 98                       Congo                    2.657927
# 87                 Ivory Coast                    2.652080
# 100                 Mozambique                    2.641415
# 8                       Israel                    2.634107
# 31                      Kosovo                    2.631157
# 54                    Honduras                    2.610586
# 108                     Guinea                    2.537801
# 92                     Gambia*                    2.531070
# 0                      Finland                    2.518052
# 48                 El Salvador                    2.513952
# 101                   Cameroon                    2.468750
# ...

# %%
reset_index_Distopia_2022 = data_Score_Dystopia_Ordenado_2022.reset_index(drop=True)
reset_index_Distopia_2022
# Out:
#                        Country  Dystopia (1.83) + residual
# 0                     Liberia*                    2.844388
# 1                    Venezuela                    2.790293
# 2                   Guatemala*                    2.746166
# 3                       Niger*                    2.666880
# 4                        Congo                    2.657927
# 5                  Ivory Coast                    2.652080
# 6                   Mozambique                    2.641415
# 7                       Israel                    2.634107
# 8                       Kosovo                    2.631157
# 9                     Honduras                    2.610586
# 10                      Guinea                    2.537801
# 11                     Gambia*                    2.531070
# 12                     Finland                    2.518052
# 13                 El Salvador                    2.513952
# 14                    Cameroon                    2.468750
# ...

# %% [markdown]
# # Avaliação do Brasil nos anos de 2022 e 2023

# %% [markdown]
# ## O Brasil ocupa a pocição 48 no ano de 2023.

# %%
data_country_score
# Out:
#                   Country name  Ladder score
# 0                      Finland        7.8042
# 1                      Denmark        7.5864
# 2                      Iceland        7.5296
# 3                       Israel        7.4729
# 4                  Netherlands        7.4030
# 5                       Sweden        7.3952
# 6                       Norway        7.3155
# 7                  Switzerland        7.2401
# 8                   Luxembourg        7.2279
# 9                  New Zealand        7.1229
# 10                     Austria        7.0973
# 11                   Australia        7.0946
# 12                      Canada        6.9607
# 13                     Ireland        6.9108
# 14               United States        6.8937
# 15                     Germany        6.8918
# 16                     Belgium        6.8591
# 17                     Czechia        6.8452
# 18              United Kingdom        6.7956
# 19                   Lithuania        6.7630
# ...

# %% [markdown]
# ## O Brasil ocupa a posição 37 no ano de 2022.

# %%
data2022_country_score
# Out:
#                        Country  RANK  Happiness score
# 0                      Finland     1           7.8210
# 1                      Denmark     2           7.6362
# 2                      Iceland     3           7.5575
# 3                  Switzerland     4           7.5116
# 4                  Netherlands     5           7.4149
# 5                  Luxembourg*     6           7.4040
# 6                       Sweden     7           7.3843
# 7                       Norway     8           7.3651
# 8                       Israel     9           7.3638
# 9                  New Zealand    10           7.1998
# 10                     Austria    11           7.1630
# 11                   Australia    12           7.1621
# 12                     Ireland    13           7.0408
# 13                     Germany    14           7.0341
# 14                      Canada    15           7.0251
# 15               United States    16           6.9768
# ...

# %% [markdown]
# ### Em 2022, o Brasil detinha a 37ª posição no ranking de países mais felizes. No entanto, ocorreu uma queda em 2023, e o país deslocou-se para a 48ª posição, indicando uma diminuição relativa na avaliação de felicidade. Essa mudança sugere uma possível variação no bem-estar percebido ao longo desses dois anos, refletindo em uma posição menos favorável no cenário global de felicidade.

# %% [markdown]
# # Brasil
#
# ## Percepção sobre a corrupção 2022

# %%
corrupion_ordenado_2022
# Out:
#                        Country  Explained by: Perceptions of corruption
# 0                    Singapore                                 0.586828
# 1                      Rwanda*                                 0.544236
# 2                      Finland                                 0.533658
# 3                      Denmark                                 0.532079
# 4                       Sweden                                 0.512238
# 5                  New Zealand                                 0.483003
# 6                       Norway                                 0.473999
# 7                  Switzerland                                 0.461004
# 8                  Netherlands                                 0.419083
# 9                      Ireland                                 0.407679
# 10                 Luxembourg*                                 0.388120
# 11   Hong Kong S.A.R. of China                                 0.382751
# ...

# %% [markdown]
# ## Percepção sobre a corrupção 2023

# %%
corrupion_ordenado
# Out:
#                   Country name  Explained by: Perceptions of corruption
# 0                    Singapore                                 0.560821
# 1                      Finland                                 0.535299
# 2                      Denmark                                 0.525221
# 3                       Sweden                                 0.520469
# 4                  Switzerland                                 0.474700
# 5                  New Zealand                                 0.471221
# 6                       Norway                                 0.462955
# 7                   Luxembourg                                 0.418380
# 8                      Ireland                                 0.409087
# 9                  Netherlands                                 0.394062
# 10   Hong Kong S.A.R. of China                                 0.389993
# 11                     Estonia                                 0.372188
# ...

# %% [markdown]
# ## Em relação à percepção da corrupção, o Brasil ocupava a 65ª posição no ranking em 2022. Contudo, em 2023, houve uma melhoria nessa avaliação, e o país avançou para a 54ª posição, Mas segundo o IPC ( índice de percepção da corrupção) , Houve uma queda na pontuação do Brasil no  ano de 2023 , Caindo 10 posições, terminando na 104ª colocação entre os 180 países avaliados.

# %% [markdown]
# ## Ladder score in Dystopia 2023

# %%
data_Score_Dystopia_Ordenado_index
# Out:
#                   Country name  Dystopia + residual
# 0                    Venezuela             2.954561
# 1          Congo (Brazzaville)             2.802217
# 2                       Guinea             2.704875
# 3                       Israel             2.691290
# 4                     Honduras             2.630738
# 5                    Guatemala             2.561968
# 6                   Mozambique             2.519486
# 7                  Ivory Coast             2.518610
# 8                      Romania             2.485311
# 9                    Nicaragua             2.448323
# 10                    Cameroon             2.410614
# 11                 El Salvador             2.403147
# 12                      Kosovo             2.392719
# 13                      Mexico             2.388729
# 14                   Lithuania             2.377429
# 15                     Finland             2.363241
# 16                       Niger             2.341015
# ...

# %% [markdown]
# ## Ladder score in Dystopia 2022

# %%
reset_index_Distopia_2022
# Out:
#                        Country  Dystopia (1.83) + residual
# 0                     Liberia*                    2.844388
# 1                    Venezuela                    2.790293
# 2                   Guatemala*                    2.746166
# 3                       Niger*                    2.666880
# 4                        Congo                    2.657927
# 5                  Ivory Coast                    2.652080
# 6                   Mozambique                    2.641415
# 7                       Israel                    2.634107
# 8                       Kosovo                    2.631157
# 9                     Honduras                    2.610586
# 10                      Guinea                    2.537801
# 11                     Gambia*                    2.531070
# 12                     Finland                    2.518052
# 13                 El Salvador                    2.513952
# 14                    Cameroon                    2.468750
# ...

# %% [markdown]
# ### Em 2022 e 2023, o Brasil permanece na 22ª posição na avaliação de dystopia. Essa consistência sugere estabilidade ao longo desses dois anos, indicando que, na perspectiva de dystopia, o país mantém uma posição constante no cenário global.

# %%
data
# Out:
#                   Country name  Ladder score  Standard error of ladder score  \
# 0                      Finland        7.8042                        0.036162
# 1                      Denmark        7.5864                        0.041028
# 2                      Iceland        7.5296                        0.048612
# 3                       Israel        7.4729                        0.031609
# 4                  Netherlands        7.4030                        0.029294
# 5                       Sweden        7.3952                        0.037362
# 6                       Norway        7.3155                        0.044143
# 7                  Switzerland        7.2401                        0.042789
# 8                   Luxembourg        7.2279                        0.069081
# 9                  New Zealand        7.1229                        0.038227
# 10                     Austria        7.0973                        0.040401
# ...

# %% [markdown]
# ## Dataset Brasil 2023

# %%
Brasil_2023 = data.iloc[48]
Brasil_2023
# Out:
# Country name                                     Brazil
# Ladder score                                     6.1246
# Standard error of ladder score                 0.064858
# upperwhisker                                   6.251721
# lowerwhisker                                   5.997479
# Logged GDP per capita                          9.582188
# Social support                                 0.836277
# Healthy life expectancy                       65.748711
# Freedom to make life choices                   0.801329
# Generosity                                     -0.00937
# Perceptions of corruption                      0.737685
# Ladder score in Dystopia                       1.777825
# Explained by: Log GDP per capita               1.454481
# Explained by: Social support                   1.250219
# Explained by: Healthy life expectancy          0.387407
# Explained by: Freedom to make life choices     0.558488
# Explained by: Generosity                       0.131404
# ...

# %%
Brasil_df_2023 = pd.DataFrame([Brasil_2023])
Brasil_df_2023
# Out:
#    Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 48       Brazil        6.1246                        0.064858      6.251721
#
#     lowerwhisker  Logged GDP per capita  Social support  \
# 48      5.997479               9.582188        0.836277
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 48                65.748711                      0.801329    -0.00937
#
#     Perceptions of corruption  Ladder score in Dystopia  \
# 48                   0.737685                  1.777825
#
#     Explained by: Log GDP per capita  Explained by: Social support  \
# 48                          1.454481                      1.250219
#
#     Explained by: Healthy life expectancy  \
# 48                               0.387407
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# 48                                    0.558488                  0.131404
#
# ...

# %%
data2022
# Out:
#      RANK                    Country  Happiness score  Whisker-high  \
# 0       1                    Finland           7.8210      7.886425
# 1       2                    Denmark           7.6362      7.709897
# 2       3                    Iceland           7.5575      7.651076
# 3       4                Switzerland           7.5116      7.586394
# 4       5                Netherlands           7.4149      7.471265
# 5       6                Luxembourg*           7.4040      7.501348
# 6       7                     Sweden           7.3843      7.454091
# 7       8                     Norway           7.3651      7.439799
# 8       9                     Israel           7.3638      7.426288
# 9      10                New Zealand           7.1998      7.279399
# 10     11                    Austria           7.1630      7.236605
# 11     12                  Australia           7.1621      7.243522
# 12     13                    Ireland           7.0408      7.120752
# ...

# %% [markdown]
# ## Dataset Brasil 2022

# %%
Brasil_2022 = data2022.iloc[37]
Brasil_2022
# Out:
# RANK                                                38
# Country                                         Brazil
# Happiness score                                 6.2928
# Whisker-high                                  6.383821
# Whisker-low                                   6.201779
# Dystopia (1.83) + residual                    2.360507
# Explained by: GDP per capita                  1.461886
# Explained by: Social support                  1.044197
# Explained by: Healthy life expectancy         0.614587
# Explained by: Freedom to make life choices    0.546346
# Explained by: Generosity                      0.131041
# Explained by: Perceptions of corruption       0.134278
# nota_arredondada_score                             6.0
# Name: 37, dtype: object

# %%
Brasil_df_2022 = pd.DataFrame([Brasil_2022])
Brasil_df_2022
# Out:
#     RANK Country  Happiness score  Whisker-high  Whisker-low  \
# 37    38  Brazil           6.2928      6.383821     6.201779
#
#     Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 37                    2.360507                      1.461886
#
#     Explained by: Social support  Explained by: Healthy life expectancy  \
# 37                      1.044197                               0.614587
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# 37                                    0.546346                  0.131041
#
#     Explained by: Perceptions of corruption  nota_arredondada_score
# 37                                 0.134278                     6.0

# %% [markdown]
# ## Comparativo das notas do Brasil  de 2022 e 2023

# %%
Brasil_df_2022
# Out:
#     RANK Country  Happiness score  Whisker-high  Whisker-low  \
# 37    38  Brazil           6.2928      6.383821     6.201779
#
#     Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 37                    2.360507                      1.461886
#
#     Explained by: Social support  Explained by: Healthy life expectancy  \
# 37                      1.044197                               0.614587
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# 37                                    0.546346                  0.131041
#
#     Explained by: Perceptions of corruption  nota_arredondada_score
# 37                                 0.134278                     6.0

# %% [markdown]
# ## Gráfico de dispersão 2022

# %%
variaveis = ['Happiness score', 'Explained by: GDP per capita', 'Explained by: Social support',
             'Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices',
             'Explained by: Generosity', 'Explained by: Perceptions of corruption']

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12, 8))

for variavel in variaveis:
    sns.scatterplot(x=variavel, y='Country', data=Brasil_df_2022, label=variavel)

plt.title('Gráfico de Dispersão - Braisil 2022')
plt.ylabel('Pontuação')
# Out:
# Text(0, 0.5, 'Pontuação')

# %% [markdown]
# ## Gráfico de dispersão 2023

# %%
variaveis_2023 = ['Ladder score', 'Logged GDP per capita', 'Social support',
             'Healthy life expectancy', 'Freedom to make life choices',
             'Generosity', 'Perceptions of corruption', 'Dystopia + residual']

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12, 8))

for variaveis_2023 in variaveis:
    sns.scatterplot(x=variaveis_2023, y='Country name', data=Brasil_df_2023, label=variaveis_2023)

plt.title('Gráfico de Dispersão - Braisil 2023')
plt.ylabel('Pontuação')
# Out:
# Text(0, 0.5, 'Pontuação')

# %% [markdown]
# ## Observamos uma distribuição uniforme no número de votos, indicando uma participação equilibrada. No entanto, notamos uma diminuição na pontuação da expectativa de vida no ano de 2023, vamos analisar .

# %% [markdown]
# # Expectativa de vida saldável 2022(Análise)

# %%
vida_Saudavel_2022 = data2022[['Country','Explained by: Healthy life expectancy']]

# %%
vida_Saudavel_2022
# Out:
#                        Country  Explained by: Healthy life expectancy
# 0                      Finland                               0.775206
# 1                      Denmark                               0.776644
# 2                      Iceland                               0.802622
# 3                  Switzerland                               0.822048
# 4                  Netherlands                               0.786738
# 5                  Luxembourg*                               0.790365
# 6                       Sweden                               0.802608
# 7                       Norway                               0.786031
# 8                       Israel                               0.817637
# 9                  New Zealand                               0.752117
# 10                     Austria                               0.773750
# 11                   Australia                               0.772304
# ...

# %%
vida_Saudavel_2022_Ordenado = vida_Saudavel_2022.sort_values(by='Explained by: Healthy life expectancy', ascending=False)

# %%
vida_Saudavel_2022_Ordenado
# Out:
#                        Country  Explained by: Healthy life expectancy
# 80   Hong Kong S.A.R. of China                               0.941829
# 53                       Japan                               0.866070
# 26                   Singapore                               0.850874
# 58                 South Korea                               0.841494
# 3                  Switzerland                               0.822048
# 78               North Cyprus*                               0.819165
# 40                      Cyprus                               0.819165
# 8                       Israel                               0.817637
# 28                       Spain                               0.808363
# 19                      France                               0.807645
# 2                      Iceland                               0.802622
# 6                       Sweden                               0.802608
# ...

# %%
vida_Saudavel_2022_Ordenado_index = vida_Saudavel_2022_Ordenado.reset_index(drop=True)

# %%
vida_Saudavel_2022_Ordenado_index
# Out:
#                        Country  Explained by: Healthy life expectancy
# 0    Hong Kong S.A.R. of China                               0.941829
# 1                        Japan                               0.866070
# 2                    Singapore                               0.850874
# 3                  South Korea                               0.841494
# 4                  Switzerland                               0.822048
# 5                North Cyprus*                               0.819165
# 6                       Cyprus                               0.819165
# 7                       Israel                               0.817637
# 8                        Spain                               0.808363
# 9                       France                               0.807645
# 10                     Iceland                               0.802622
# 11                      Sweden                               0.802608
# ...

# %% [markdown]
# # Expectativa de vida saldável 2023(Análise)

# %%
vida_Saudavel_2023 = data[['Country name','Explained by: Healthy life expectancy']]

# %%
vida_Saudavel_2023
# Out:
#                   Country name  Explained by: Healthy life expectancy
# 0                      Finland                               0.534574
# 1                      Denmark                               0.537302
# 2                      Iceland                               0.559096
# 3                       Israel                               0.576730
# 4                  Netherlands                               0.545473
# 5                       Sweden                               0.561825
# 6                       Norway                               0.544111
# 7                  Switzerland                               0.582254
# 8                   Luxembourg                               0.548878
# 9                  New Zealand                               0.512778
# 10                     Austria                               0.534575
# 11                   Australia                               0.531848
# ...

# %%
vida_Saudavel_2023_Ordenado = vida_Saudavel_2023.sort_values(by='Explained by: Healthy life expectancy', ascending=False)

# %%
vida_Saudavel_2023_Ordenado
# Out:
#                   Country name  Explained by: Healthy life expectancy
# 81   Hong Kong S.A.R. of China                               0.701590
# 46                       Japan                               0.621749
# 24                   Singapore                               0.606778
# 56                 South Korea                               0.602696
# 7                  Switzerland                               0.582254
# 45                      Cyprus                               0.579584
# 3                       Israel                               0.576730
# 31                       Spain                               0.567269
# 20                      France                               0.565909
# 5                       Sweden                               0.561825
# 2                      Iceland                               0.559096
# 32                       Italy                               0.559096
# ...

# %%
vida_Saudavel_2023_Ordenado_index = vida_Saudavel_2023_Ordenado.reset_index(drop=True)

# %%
vida_Saudavel_2023_Ordenado_index
# Out:
#                   Country name  Explained by: Healthy life expectancy
# 0    Hong Kong S.A.R. of China                               0.701590
# 1                        Japan                               0.621749
# 2                    Singapore                               0.606778
# 3                  South Korea                               0.602696
# 4                  Switzerland                               0.582254
# 5                       Cyprus                               0.579584
# 6                       Israel                               0.576730
# 7                        Spain                               0.567269
# 8                       France                               0.565909
# 9                       Sweden                               0.561825
# 10                     Iceland                               0.559096
# 11                       Italy                               0.559096
# ...

# %%
vida_Saudavel_2022_Ordenado_index
# Out:
#                        Country  Explained by: Healthy life expectancy
# 0    Hong Kong S.A.R. of China                               0.941829
# 1                        Japan                               0.866070
# 2                    Singapore                               0.850874
# 3                  South Korea                               0.841494
# 4                  Switzerland                               0.822048
# 5                North Cyprus*                               0.819165
# 6                       Cyprus                               0.819165
# 7                       Israel                               0.817637
# 8                        Spain                               0.808363
# 9                       France                               0.807645
# 10                     Iceland                               0.802622
# 11                      Sweden                               0.802608
# ...

# %% [markdown]
# ## Apesar da nota do Brasil em relação a expectativa de vida saudável, No ano de 2023 ter sido menor que a de 2022, não sabemos qual foi a métrica usada de um ano para o outro, a posição do Brasil não nodifica muito.

# %% [markdown]
# # Conclusão

# %% [markdown]
# ## Alguns países tiveram uma melhoria nas notas, especialmente no aumento das notas 7,de um ano para o outro, sugere que, enquanto o desempenho do Brasil se manteve , sem muitas alteraçães, outros países obtiveram uma satisfação melhor em seus resultados.
